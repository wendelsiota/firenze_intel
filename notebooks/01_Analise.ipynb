# %% [markdown]
# # Dados Disponiveis em https://insideairbnb.com/get-the-data/
# ## Florence,Toscana, Italy

# %%
# === 01 • Imports e paths ===
import os
import re
import numpy as np
import pandas as pd

# Caminhos do projeto
DATA_RAW = "../data/raw/listings.csv"      # ajuste se seu notebook estiver em outra pasta
DATA_OUT_DIR = "../data/processed"
os.makedirs(DATA_OUT_DIR, exist_ok=True)

pd.set_option("display.max_columns", 100)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

# %%
# === 02 • Carga do CSV e inspeção rápida ===
df = pd.read_csv(DATA_RAW, low_memory=False)
print(f"Shape bruto: {df.shape[0]} linhas × {df.shape[1]} colunas")

# Amostra e colunas
display(pd.DataFrame({"coluna": df.columns}))
display(df.dtypes)
display(df.head(3))
# Out:
# Shape bruto: 13043 linhas × 79 colunas
#                                           coluna
# 0                                             id
# 1                                    listing_url
# 2                                      scrape_id
# 3                                   last_scraped
# 4                                         source
# ..                                           ...
# 74                calculated_host_listings_count
# 75   calculated_host_listings_count_entire_homes
# 76  calculated_host_listings_count_private_rooms
# 77   calculated_host_listings_count_shared_rooms
# 78                             reviews_per_month
#
# [79 rows x 1 columns]
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 79, dtype: object
#       id                         listing_url       scrape_id last_scraped  \
# 0  31840  https://www.airbnb.com/rooms/31840  20250619031413   2025-06-19
# 1  32180  https://www.airbnb.com/rooms/32180  20250619031413   2025-06-19
# 2  39115  https://www.airbnb.com/rooms/39115  20250619031413   2025-06-19
#
#             source                                 name  \
# 0      city scrape       Residenza Martin  Classic room
# 1      city scrape  Charming Gem - Oltrarno City centre
# 2  previous scrape       Central Double Shared Bathroom
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# 1                                                  .
# 2  Double Room Shared Bathroom: comfortable, larg...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  San Lorenzo Church, the market and Cappelle Me...
#
#                                          picture_url   host_id  \
# 0  https://a0.muscache.com/pictures/prohost-api/H...    380378
# 1  https://a0.muscache.com/pictures/bcb23395-7215...  13925330
# 2  https://a0.muscache.com/pictures/17793998/5f09...    167739
#
#                                      host_url host_name  host_since  \
# 0    https://www.airbnb.com/users/show/380378    Andrea  2011-02-07
# 1  https://www.airbnb.com/users/show/13925330    Cesare  2014-04-05
# 2    https://www.airbnb.com/users/show/167739   Lorenzo  2010-07-15
#
#      host_location                                         host_about  \
# 0  Florence, Italy  360 Rentals has been offering fully furnished ...
# 1  Florence, Italy                                                  .
# 2  Florence, Italy  Casa Billi, now renewed, is centrally located ...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0      within an hour                99%                 100%
# 1        within a day                83%                  75%
# 2  within a few hours               100%                  94%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0               NaN  https://a0.muscache.com/im/pictures/user/3bf50...
# 1                 f  https://a0.muscache.com/im/users/13925330/prof...
# 2                 f  https://a0.muscache.com/im/users/167739/profil...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/pictures/user/3bf50...
# 1  https://a0.muscache.com/im/users/13925330/prof...
# 2  https://a0.muscache.com/im/users/167739/profil...
#
#            host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0              Centro Storico                   31                         39
# 1  Santo Spirito-San Frediano                    1                          1
# 2                 San Lorenzo                   11                         12
#
#                  host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'work_email']                    t
# 1                ['email', 'phone']                    t
# 2  ['email', 'phone', 'work_email']                    t
#
#   host_identity_verified             neighbourhood neighbourhood_cleansed  \
# 0                      t                       NaN         Centro Storico
# 1                      t                       NaN         Centro Storico
# 2                      t  Florence, Tuscany, Italy         Centro Storico
#
#    neighbourhood_group_cleansed  latitude  longitude  \
# 0                           NaN     43.78      11.25
# 1                           NaN     43.77      11.24
# 2                           NaN     43.78      11.25
#
#                         property_type        room_type  accommodates  \
# 0  Private room in serviced apartment     Private room             2
# 1                        Entire condo  Entire home/apt             4
# 2                Private room in home     Private room             2
#
#    bathrooms  bathrooms_text  bedrooms  beds  \
# 0       1.00  1 private bath      1.00  1.00
# 1       2.00         2 baths      2.00  3.00
# 2        NaN         0 baths       NaN   NaN
#
#                                            amenities    price  minimum_nights  \
# 0  ["43 inch HDTV with standard cable", "Wifi", "...  $130.00               1
# 1  ["Heating", "Wifi", "Oven", "Cooking basics", ...  $112.00               6
# 2  ["Room-darkening shades", "Lock on bedroom doo...      NaN               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              99                       1                       2
# 1              31                       6                       6
# 2              35                       2                       4
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                      29                      29                    2.00
# 1                    1125                    1125                    6.00
# 2                       6                      35                    2.50
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   29.00               NaN                t               11
# 1                1,125.00               NaN                t                5
# 2                   20.80               NaN                t               25
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               40               70               345            2025-06-19
# 1               32               62               162            2025-06-19
# 2               32               42               317            2025-06-19
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                156                     25                       2
# 1                 40                      7                       0
# 2                 86                      8                       0
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0               176                    11                        150
# 1               118                     3                         84
# 2               148                     6                         48
#
#    estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 0                19,500.00   2010-06-23  2025-06-05                  4.67
# 1                 9,408.00   2010-06-17  2025-05-15                  4.77
# 2                      NaN   2010-09-07  2025-05-15                  4.52
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.72                       4.85                   4.85
# 1                    4.81                       4.84                   4.78
# 2                    4.70                       4.60                   4.80
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.91                    4.89                 4.65
# 1                         4.70                    4.81                 4.84
# 2                         4.74                    4.91                 4.54
#
#               license instant_bookable  calculated_host_listings_count  \
# 0  IT048017B4R5K5BW8E                t                              24
# 1  IT048017C232S8WUEN                f                               1
# 2  IT048017B9LED47MUB                f                              11
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           14
# 1                                            1
# 2                                            3
#
#    calculated_host_listings_count_private_rooms  \
# 0                                            10
# 1                                             0
# 2                                             8
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.85
# 1                                            0               0.22
# 2                                            0               0.48

# %%
df.describe().T  #Estatísticas básicas (para colunas numéricas)
# Out:
#                                                  count  \
# id                                           13,043.00
# scrape_id                                    13,043.00
# host_id                                      13,043.00
# host_listings_count                          13,043.00
# host_total_listings_count                    13,043.00
# neighbourhood_group_cleansed                      0.00
# latitude                                     13,043.00
# longitude                                    13,043.00
# accommodates                                 13,043.00
# bathrooms                                    12,025.00
# bedrooms                                     12,918.00
# beds                                         11,998.00
# minimum_nights                               13,043.00
# maximum_nights                               13,043.00
# minimum_minimum_nights                       13,043.00
# maximum_minimum_nights                       13,043.00
# minimum_maximum_nights                       13,043.00
# maximum_maximum_nights                       13,043.00
# minimum_nights_avg_ntm                       13,043.00
# maximum_nights_avg_ntm                       13,043.00
# calendar_updated                                  0.00
# availability_30                              13,043.00
# availability_60                              13,043.00
# availability_90                              13,043.00
# availability_365                             13,043.00
# number_of_reviews                            13,043.00
# number_of_reviews_ltm                        13,043.00
# number_of_reviews_l30d                       13,043.00
# availability_eoy                             13,043.00
# number_of_reviews_ly                         13,043.00
# estimated_occupancy_l365d                    13,043.00
# estimated_revenue_l365d                      12,026.00
# review_scores_rating                         11,627.00
# review_scores_accuracy                       11,627.00
# review_scores_cleanliness                    11,627.00
# review_scores_checkin                        11,627.00
# review_scores_communication                  11,627.00
# review_scores_location                       11,627.00
# review_scores_value                          11,627.00
# calculated_host_listings_count               13,043.00
# calculated_host_listings_count_entire_homes  13,043.00
# calculated_host_listings_count_private_rooms 13,043.00
# calculated_host_listings_count_shared_rooms  13,043.00
# reviews_per_month                            11,627.00
#
#                                                                    mean  \
# id                                           622,886,029,992,062,976.00
# scrape_id                                         20,250,619,031,413.00
# host_id                                                  200,215,010.85
# host_listings_count                                               38.14
# host_total_listings_count                                         52.24
# neighbourhood_group_cleansed                                        NaN
# latitude                                                          43.77
# longitude                                                         11.25
# accommodates                                                       3.85
# bathrooms                                                          1.36
# bedrooms                                                           1.54
# beds                                                               2.23
# minimum_nights                                                     5.28
# maximum_nights                                                   372.76
# minimum_minimum_nights                                             4.63
# maximum_minimum_nights                                             6.01
# minimum_maximum_nights                                       823,776.93
# maximum_maximum_nights                                       823,858.63
# minimum_nights_avg_ntm                                             5.29
# maximum_nights_avg_ntm                                       823,824.98
# calendar_updated                                                    NaN
# availability_30                                                   11.89
# availability_60                                                   29.86
# availability_90                                                   48.47
# availability_365                                                 208.60
# number_of_reviews                                                 73.81
# number_of_reviews_ltm                                             16.99
# number_of_reviews_l30d                                             1.85
# availability_eoy                                                 117.08
# number_of_reviews_ly                                              16.36
# estimated_occupancy_l365d                                         94.60
# estimated_revenue_l365d                                       18,551.53
# review_scores_rating                                               4.75
# review_scores_accuracy                                             4.80
# review_scores_cleanliness                                          4.78
# review_scores_checkin                                              4.83
# review_scores_communication                                        4.84
# review_scores_location                                             4.82
# review_scores_value                                                4.68
# calculated_host_listings_count                                    20.30
# calculated_host_listings_count_entire_homes                       19.16
# calculated_host_listings_count_private_rooms                       1.10
# calculated_host_listings_count_shared_rooms                        0.00
# reviews_per_month                                                  1.94
#
#                                                                     std  \
# id                                           558,278,477,222,212,800.00
# scrape_id                                                          0.00
# host_id                                                  212,409,700.38
# host_listings_count                                              111.89
# host_total_listings_count                                        180.31
# neighbourhood_group_cleansed                                        NaN
# latitude                                                           0.01
# longitude                                                          0.02
# accommodates                                                       1.91
# bathrooms                                                          0.70
# bedrooms                                                           0.88
# beds                                                               1.44
# minimum_nights                                                    17.31
# maximum_nights                                                   418.13
# minimum_minimum_nights                                            16.83
# maximum_minimum_nights                                            18.93
# minimum_maximum_nights                                    42,039,679.91
# maximum_maximum_nights                                    42,039,678.31
# minimum_nights_avg_ntm                                            17.56
# maximum_nights_avg_ntm                                    42,039,678.97
# calendar_updated                                                    NaN
# availability_30                                                    9.19
# availability_60                                                   18.24
# availability_90                                                   26.93
# availability_365                                                 111.21
# number_of_reviews                                                114.46
# number_of_reviews_ltm                                             20.77
# number_of_reviews_l30d                                             2.44
# availability_eoy                                                  56.98
# number_of_reviews_ly                                              21.26
# estimated_occupancy_l365d                                         95.16
# estimated_revenue_l365d                                       54,014.66
# review_scores_rating                                               0.35
# review_scores_accuracy                                             0.32
# review_scores_cleanliness                                          0.34
# review_scores_checkin                                              0.29
# review_scores_communication                                        0.30
# review_scores_location                                             0.27
# review_scores_value                                                0.37
# calculated_host_listings_count                                    46.83
# calculated_host_listings_count_entire_homes                       46.62
# calculated_host_listings_count_private_rooms                       2.87
# calculated_host_listings_count_shared_rooms                        0.14
# reviews_per_month                                                  1.77
#
#                                                                min  \
# id                                                       31,840.00
# scrape_id                                    20,250,619,031,413.00
# host_id                                                  15,651.00
# host_listings_count                                           1.00
# host_total_listings_count                                     1.00
# neighbourhood_group_cleansed                                   NaN
# latitude                                                     43.73
# longitude                                                    11.16
# accommodates                                                  1.00
# bathrooms                                                     0.00
# bedrooms                                                      0.00
# beds                                                          0.00
# minimum_nights                                                1.00
# maximum_nights                                                1.00
# minimum_minimum_nights                                        1.00
# maximum_minimum_nights                                        1.00
# minimum_maximum_nights                                        1.00
# maximum_maximum_nights                                        1.00
# minimum_nights_avg_ntm                                        1.00
# maximum_nights_avg_ntm                                        1.00
# calendar_updated                                               NaN
# availability_30                                               0.00
# availability_60                                               0.00
# availability_90                                               0.00
# availability_365                                              0.00
# number_of_reviews                                             0.00
# number_of_reviews_ltm                                         0.00
# number_of_reviews_l30d                                        0.00
# availability_eoy                                              0.00
# number_of_reviews_ly                                          0.00
# estimated_occupancy_l365d                                     0.00
# estimated_revenue_l365d                                       0.00
# review_scores_rating                                          1.00
# review_scores_accuracy                                        1.00
# review_scores_cleanliness                                     1.00
# review_scores_checkin                                         1.00
# review_scores_communication                                   1.00
# review_scores_location                                        1.00
# review_scores_value                                           1.00
# calculated_host_listings_count                                1.00
# calculated_host_listings_count_entire_homes                   0.00
# calculated_host_listings_count_private_rooms                  0.00
# calculated_host_listings_count_shared_rooms                   0.00
# reviews_per_month                                             0.01
#
#                                                                25%  \
# id                                                   30,541,062.50
# scrape_id                                    20,250,619,031,413.00
# host_id                                              23,904,874.00
# host_listings_count                                           1.00
# host_total_listings_count                                     2.00
# neighbourhood_group_cleansed                                   NaN
# latitude                                                     43.77
# longitude                                                    11.25
# accommodates                                                  2.00
# bathrooms                                                     1.00
# bedrooms                                                      1.00
# beds                                                          1.00
# minimum_nights                                                1.00
# maximum_nights                                               29.00
# minimum_minimum_nights                                        1.00
# maximum_minimum_nights                                        2.00
# minimum_maximum_nights                                       30.00
# maximum_maximum_nights                                       60.00
# minimum_nights_avg_ntm                                        1.50
# maximum_nights_avg_ntm                                       60.00
# calendar_updated                                               NaN
# availability_30                                               4.00
# availability_60                                              15.00
# availability_90                                              28.00
# availability_365                                            118.00
# number_of_reviews                                             4.00
# number_of_reviews_ltm                                         1.00
# number_of_reviews_l30d                                        0.00
# availability_eoy                                             80.00
# number_of_reviews_ly                                          0.00
# estimated_occupancy_l365d                                     6.00
# estimated_revenue_l365d                                   1,218.00
# review_scores_rating                                          4.67
# review_scores_accuracy                                        4.75
# review_scores_cleanliness                                     4.71
# review_scores_checkin                                         4.79
# review_scores_communication                                   4.81
# review_scores_location                                        4.75
# review_scores_value                                           4.59
# calculated_host_listings_count                                1.00
# calculated_host_listings_count_entire_homes                   1.00
# calculated_host_listings_count_private_rooms                  0.00
# calculated_host_listings_count_shared_rooms                   0.00
# reviews_per_month                                             0.52
#
#                                                                     50%  \
# id                                           761,488,686,508,963,712.00
# scrape_id                                         20,250,619,031,413.00
# host_id                                                   96,122,546.00
# host_listings_count                                                4.00
# host_total_listings_count                                          5.00
# neighbourhood_group_cleansed                                        NaN
# latitude                                                          43.77
# longitude                                                         11.25
# accommodates                                                       4.00
# bathrooms                                                          1.00
# bedrooms                                                           1.00
# beds                                                               2.00
# minimum_nights                                                     2.00
# maximum_nights                                                   365.00
# minimum_minimum_nights                                             2.00
# maximum_minimum_nights                                             2.00
# minimum_maximum_nights                                           365.00
# maximum_maximum_nights                                           365.00
# minimum_nights_avg_ntm                                             2.00
# maximum_nights_avg_ntm                                           365.00
# calendar_updated                                                    NaN
# availability_30                                                   10.00
# availability_60                                                   30.00
# availability_90                                                   51.00
# availability_365                                                 229.00
# number_of_reviews                                                 27.00
# number_of_reviews_ltm                                              8.00
# number_of_reviews_l30d                                             1.00
# availability_eoy                                                 128.00
# number_of_reviews_ly                                               6.00
# estimated_occupancy_l365d                                         60.00
# estimated_revenue_l365d                                        8,970.00
# review_scores_rating                                               4.84
# review_scores_accuracy                                             4.88
# review_scores_cleanliness                                          4.88
# review_scores_checkin                                              4.91
# review_scores_communication                                        4.93
# review_scores_location                                             4.90
# review_scores_value                                                4.77
# calculated_host_listings_count                                     3.00
# calculated_host_listings_count_entire_homes                        2.00
# calculated_host_listings_count_private_rooms                       0.00
# calculated_host_listings_count_shared_rooms                        0.00
# reviews_per_month                                                  1.45
#
#                                                                       75%  \
# id                                           1,145,495,493,978,345,600.00
# scrape_id                                           20,250,619,031,413.00
# host_id                                                    400,873,265.00
# host_listings_count                                                 18.00
# host_total_listings_count                                           21.00
# neighbourhood_group_cleansed                                          NaN
# latitude                                                            43.78
# longitude                                                           11.26
# accommodates                                                         5.00
# bathrooms                                                            2.00
# bedrooms                                                             2.00
# beds                                                                 3.00
# minimum_nights                                                       3.00
# maximum_nights                                                     365.00
# minimum_minimum_nights                                               2.00
# maximum_minimum_nights                                               3.00
# minimum_maximum_nights                                           1,125.00
# maximum_maximum_nights                                           1,125.00
# minimum_nights_avg_ntm                                               3.00
# maximum_nights_avg_ntm                                           1,125.00
# calendar_updated                                                      NaN
# availability_30                                                     19.00
# availability_60                                                     45.00
# availability_90                                                     71.00
# availability_365                                                   307.00
# number_of_reviews                                                   91.00
# number_of_reviews_ltm                                               27.00
# number_of_reviews_l30d                                               3.00
# availability_eoy                                                   164.00
# number_of_reviews_ly                                                27.00
# estimated_occupancy_l365d                                          180.00
# estimated_revenue_l365d                                         24,000.00
# review_scores_rating                                                 4.95
# review_scores_accuracy                                               4.97
# review_scores_cleanliness                                            4.97
# review_scores_checkin                                                4.99
# review_scores_communication                                          5.00
# review_scores_location                                               4.98
# review_scores_value                                                  4.89
# calculated_host_listings_count                                      12.00
# calculated_host_listings_count_entire_homes                         10.00
# calculated_host_listings_count_private_rooms                         0.00
# calculated_host_listings_count_shared_rooms                          0.00
# reviews_per_month                                                    2.91
#
#                                                                       max
# id                                           1,445,707,575,918,672,384.00
# scrape_id                                           20,250,619,031,413.00
# host_id                                                    701,639,688.00
# host_listings_count                                              1,608.00
# host_total_listings_count                                        8,730.00
# neighbourhood_group_cleansed                                          NaN
# latitude                                                            43.83
# longitude                                                           11.34
# accommodates                                                        16.00
# bathrooms                                                           13.50
# bedrooms                                                            13.00
# beds                                                                17.00
# minimum_nights                                                     600.00
# maximum_nights                                                   3,000.00
# minimum_minimum_nights                                             600.00
# maximum_minimum_nights                                             600.00
# minimum_maximum_nights                                   2,147,483,647.00
# maximum_maximum_nights                                   2,147,483,647.00
# minimum_nights_avg_ntm                                             600.00
# maximum_nights_avg_ntm                                   2,147,483,647.00
# calendar_updated                                                      NaN
# availability_30                                                     30.00
# availability_60                                                     60.00
# availability_90                                                     90.00
# availability_365                                                   365.00
# number_of_reviews                                                1,174.00
# number_of_reviews_ltm                                              162.00
# number_of_reviews_l30d                                              18.00
# availability_eoy                                                   196.00
# number_of_reviews_ly                                               151.00
# estimated_occupancy_l365d                                          255.00
# estimated_revenue_l365d                                      2,550,000.00
# review_scores_rating                                                 5.00
# review_scores_accuracy                                               5.00
# review_scores_cleanliness                                            5.00
# review_scores_checkin                                                5.00
# review_scores_communication                                          5.00
# review_scores_location                                               5.00
# review_scores_value                                                  5.00
# calculated_host_listings_count                                     242.00
# calculated_host_listings_count_entire_homes                        242.00
# calculated_host_listings_count_private_rooms                        29.00
# calculated_host_listings_count_shared_rooms                          5.00
# reviews_per_month                                                   13.91

# %%
# === 03 • Helpers de limpeza ===

def to_float_price(series):
    """Converte preço textual ('$1,234.00') para float. Mantém NaN se vazio."""
    return (
        series.astype(str)
              .str.replace(r"[^\d\.\,]", "", regex=True)   # remove tudo que não é número/ponto/vírgula
              .str.replace(",", "", regex=False)           # remove separador de milhar
              .replace({"": np.nan, "nan": np.nan})
              .astype(float)
    )

def coerce_numeric(series):
    """Converte para numérico de forma tolerante (erros viram NaN)."""
    return pd.to_numeric(series, errors="coerce")

def true_false_to_int(series):
    """Converte 't'/'f' ou True/False em 1/0."""
    return series.map({True:1, False:0, "t":1, "f":0}).astype("float")

# %%
# === 04 • Limpeza de campos essenciais ===

df["price"] = to_float_price(df["price"])

# Numéricos relevantes
for col in ["accommodates","bedrooms","beds","minimum_nights","maximum_nights",
            "number_of_reviews","reviews_per_month","review_scores_rating",
            "bathrooms","bathrooms_text","availability_365","availability_90",
            "availability_30"]:
    if col in df.columns:
        df[col] = coerce_numeric(df[col])

# Bools/categóricos simples
for col in ["instant_bookable","host_is_superhost"]:
    if col in df.columns:
        df[col] = true_false_to_int(df[col])

# Latitude/Longitude
if "latitude" in df.columns: df["latitude"] = coerce_numeric(df["latitude"])
if "longitude" in df.columns: df["longitude"] = coerce_numeric(df["longitude"])

# Padroniza alguns categóricos para category (one-hot será depois)
cat_cols = ["room_type","property_type","neighbourhood_cleansed"]
for c in cat_cols:
    if c in df.columns:
        df[c] = df[c].astype("category")

print("Campos essenciais limpos.")
df[["price","accommodates","bedrooms","bathrooms","beds","room_type","property_type",
    "latitude","longitude","number_of_reviews","reviews_per_month","review_scores_rating",
    "instant_bookable","host_is_superhost","availability_365"]].head(3)
# Out:
# Campos essenciais limpos.
#    price  accommodates  bedrooms  bathrooms  beds        room_type  \
# 0 130.00             2      1.00       1.00  1.00     Private room
# 1 112.00             4      2.00       2.00  3.00  Entire home/apt
# 2    NaN             2       NaN        NaN   NaN     Private room
#
#                         property_type  latitude  longitude  number_of_reviews  \
# 0  Private room in serviced apartment     43.78      11.25                156
# 1                        Entire condo     43.77      11.24                 40
# 2                Private room in home     43.78      11.25                 86
#
#    reviews_per_month  review_scores_rating  instant_bookable  \
# 0               0.85                  4.67              1.00
# 1               0.22                  4.77              0.00
# 2               0.48                  4.52              0.00
#
#    host_is_superhost  availability_365
# 0                NaN               345
# 1               0.00               162
# 2               0.00               317

# %%
# === 05 • Seleção de features para o baseline de regressão ===

FEATURES = [
    # localização
    "latitude","longitude",
    # tipo/uso
    "room_type","property_type",
    # capacidade
    "accommodates","bedrooms","bathrooms","beds",
    # reputação/demanda
    "number_of_reviews","reviews_per_month","review_scores_rating",
    # operação
    "minimum_nights","maximum_nights","availability_365",
    # conveniência/boas práticas
    "instant_bookable","host_is_superhost"
]

TARGET = "price"

# Garante que só usamos colunas que existem no dataset atual
FEATURES = [c for c in FEATURES if c in df.columns]
cols_modelo = [c for c in FEATURES] + [TARGET]

df_model = df[cols_modelo].copy()

# Remover duplicatas (caso existam)
df_model = df_model.drop_duplicates()

# Remover linhas sem target ou com lat/long ausentes (essenciais pro heatmap futuro)
req_cols = [TARGET, "latitude", "longitude"]
req_cols_existentes = [c for c in req_cols if c in df_model.columns]
df_model = df_model.dropna(subset=req_cols_existentes)

print(f"Shape df_model (pré-tratamento de NaNs em features): {df_model.shape}")
missing = df_model.isna().sum().sort_values(ascending=False)
display(missing[missing>0].to_frame("n_missing"))
# Out:
# Shape df_model (pré-tratamento de NaNs em features): (12025, 17)
#                       n_missing
# review_scores_rating       1258
# reviews_per_month          1258
# host_is_superhost           881
# beds                         30
# bathrooms                     3
# bedrooms                      3

# %%
# === 06 • Tratamento de faltantes + cap de outliers simples ===

# 1) Drop de faltantes nas features numéricas essenciais do baseline
numeric_essentials = ["accommodates","bedrooms","bathrooms","beds",
                      "number_of_reviews","reviews_per_month",
                      "review_scores_rating","minimum_nights","maximum_nights",
                      "availability_365"]
numeric_essentials = [c for c in numeric_essentials if c in df_model.columns]

df_model = df_model.dropna(subset=[c for c in numeric_essentials if c in df_model.columns])

# 2) Cap (winsorization leve) em colunas com caudas longas
def cap_outliers(s, low_q=0.01, high_q=0.99):
    lo, hi = s.quantile([low_q, high_q])
    return s.clip(lo, hi)

to_cap = ["price","accommodates","bedrooms","bathrooms","beds",
          "minimum_nights","maximum_nights","number_of_reviews",
          "reviews_per_month","availability_365","review_scores_rating"]
to_cap = [c for c in to_cap if c in df_model.columns]

for c in to_cap:
    df_model[c] = cap_outliers(df_model[c])

# 3) Remoção de valores obviamente inválidos (exemplos)
if "price" in df_model.columns:
    df_model = df_model[df_model["price"] > 0]

if "accommodates" in df_model.columns:
    df_model = df_model[df_model["accommodates"] >= 1]

print(f"Shape df_model (pós-limpeza baseline): {df_model.shape}")
display(df_model.describe(include="all").transpose().head(20))
# Out:
# Shape df_model (pós-limpeza baseline): (10743, 17)
#                          count unique                 top  freq   mean    std  \
# latitude             10,743.00    NaN                 NaN   NaN  43.77   0.01
# longitude            10,743.00    NaN                 NaN   NaN  11.25   0.02
# room_type                10743      4     Entire home/apt  9229    NaN    NaN
# property_type            10743     47  Entire rental unit  6093    NaN    NaN
# accommodates         10,743.00    NaN                 NaN   NaN   3.84   1.78
# bedrooms             10,743.00    NaN                 NaN   NaN   1.51   0.78
# bathrooms            10,743.00    NaN                 NaN   NaN   1.34   0.60
# beds                 10,743.00    NaN                 NaN   NaN   2.20   1.30
# number_of_reviews    10,743.00    NaN                 NaN   NaN  83.65 113.66
# reviews_per_month    10,743.00    NaN                 NaN   NaN   1.98   1.72
# review_scores_rating 10,743.00    NaN                 NaN   NaN   4.76   0.27
# minimum_nights       10,743.00    NaN                 NaN   NaN   3.62   6.80
# maximum_nights       10,743.00    NaN                 NaN   NaN 362.18 422.85
# availability_365     10,743.00    NaN                 NaN   NaN 216.04 103.54
# instant_bookable     10,743.00    NaN                 NaN   NaN   0.64   0.48
# host_is_superhost     9,945.00    NaN                 NaN   NaN   0.49   0.50
# price                10,743.00    NaN                 NaN   NaN 194.15 189.60
#
#                        min    25%    50%    75%      max
# latitude             43.73  43.77  43.77  43.78    43.83
# longitude            11.16  11.25  11.25  11.26    11.34
# room_type              NaN    NaN    NaN    NaN      NaN
# property_type          NaN    NaN    NaN    NaN      NaN
# accommodates          1.00   2.00   4.00   5.00    10.00
# bedrooms              0.00   1.00   1.00   2.00     4.00
# bathrooms             1.00   1.00   1.00   2.00     4.00
# beds                  0.00   1.00   2.00   3.00     7.00
# number_of_reviews     1.00  10.00  38.00 108.00   564.74
# reviews_per_month     0.03   0.58   1.52   2.99     7.49
# review_scores_rating  3.50   4.67   4.84   4.95     5.00
# minimum_nights        1.00   1.00   2.00   3.00    31.00
# maximum_nights        7.00  29.00 150.00 365.00 1,125.00
# availability_365      0.00 133.00 235.00 307.00   365.00
# instant_bookable      0.00   0.00   1.00   1.00     1.00
# host_is_superhost     0.00   0.00   0.00   1.00     1.00
# price                45.00 102.00 139.00 205.00 1,337.40

# %%
# === 07 • Persistência para os próximos passos ===

OUT_CSV = os.path.join(DATA_OUT_DIR, "listings_model_baseline.csv")
df_model.to_csv(OUT_CSV, index=False, encoding="utf-8")
print(f"Arquivo salvo em: {OUT_CSV}")
# Out:
# Arquivo salvo em: ../data/processed/listings_model_baseline.csv
